# %%
import pandas as pd

df_answers = pd.read_csv("data/rag-answers-new.csv")
answers = df_answers.to_dict(orient="records")

# %%
from pydantic import BaseModel, Field
from typing import Literal

class AnswerEvaluation(BaseModel):
    reasoning: str = Field(
        description = "Reasoning about the quality of the answer."
    )
    score: Literal["good", "bad"] = Field(
        description = "'good' if the answer is correct and complete, 'bad' otherwise"
    )

# %%
aqa_judge_instructions = """
You are an expert evaluator. You will be given:
1. A question from a student
2. The original answer from the FAQ (ground truth)
3. An answer generated by an AI assistant

Your task is to decide if the AI answer is semantically equivalent to
the original answer.

Rules:
- The AI answer does NOT need to be word-for-word identical
- It should convey the same key information
- Extra detail is fine as long as the core answer is correct
- Mark 'bad' only if the AI answer is wrong or misses the key point

Be fair and focus on correctness, not style.
""".strip()

# %%
aqa_judge_prompt = """
Question:
{question}

Original Answer (ground truth):
{answer_orig}

AI Answer:
{answer_llm}
""".strip()

# %%
from dotenv import load_dotenv
from openai import OpenAI
from evaluation_utils import calc_total_price, llm_structured_retry, map_progress
import os
load_dotenv()

openai_client = OpenAI(
    api_key = os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
rec = answers[0]

# %%
prompt = aqa_judge_prompt.format(
    question =rec['question'],
    answer_orig = rec['answer_orig'],
    answer_llm = rec['answer_llm']
)

# %%
eval_result, usage = llm_structured_retry(
    openai_client,
    aqa_judge_instructions,
    prompt,
    AnswerEvaluation,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 eval_result, usage = llm_structured_retry(
#       2     openai_client,
#       3     aqa_judge_instructions,
#       4     prompt,
#
# NameError: name 'llm_structured_retry' is not defined

# %%
calc_price(usage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 calc_price(usage)
#
# NameError: name 'calc_price' is not defined

# %%
def evaluate_aqa(question, answer_orig, answer_llm, model="llama-3.3-70b-versatile"):
    prompt = aqa_judge_prompt.format(
        question=question,
        answer_orig=answer_orig,
        answer_llm=answer_llm
    )

    result, usage = llm_structured_retry(
        openai_client,
        aqa_judge_instructions,
        prompt,
        AnswerEvaluation,
        model=model,
    )

    return result, usage

# %%
eval_result, usage = evaluate_aqa(
    question=rec["question"],
    answer_orig=rec["answer_orig"],
    answer_llm=rec["answer_llm"]
)

eval_result
# Out:
# Rate limit or API error encountered. Retrying in 15 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# File /workspaces/LLM-zoomcamp/evaluation_utils.py:69, in llm_structured_retry(client, instructions, user_prompt, output_type, model, max_retries)
#      68 try:
# ---> 69     return llm_structured(
#      70         client,
#      71         instructions,
#      72         user_prompt,
#      73         output_type,
#      74         model=model,
#      75     )
#      76 except Exception as e:
#      77     # If we hit a rate limit, wait longer on each retry attempt
#
# File /workspaces/LLM-zoomcamp/evaluation_utils.py:42, in llm_structured(client, instructions, user_prompt, output_type, model)
#      37 messages = [
#      38     {"role": "system", "content": instructions},
#      39     {"role": "user", "content": user_prompt}
#      40 ]
# ---> 42 response = client.chat.completions.create(
#      43     model=model,
#      44     messages=messages,
#      45     response_format={"type": "json_object"},
#      46     max_completion_tokens=2000,
#      47     extra_body={"reasoning_format": "hidden", "reasoning_effort": "none"}
#      48 )
#      50 content = response.choices[0].message.content
#
# File /workspaces/LLM-zoomcamp/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File /workspaces/LLM-zoomcamp/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1281, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1280 validate_response_format(response_format)
# -> 1281 return self._post(
#    1282     "/chat/completions",
#    1283     body=maybe_transform(
#    1284         {
#    1285             "messages": messages,
#    1286             "model": model,
#    1287             "audio": audio,
#    1288             "frequency_penalty": frequency_penalty,
#    1289             "function_call": function_call,
#    1290             "functions": functions,
#    1291             "logit_bias": logit_bias,
#    1292             "logprobs": logprobs,
#    1293             "max_completion_tokens": max_completion_tokens,
#    1294             "max_tokens": max_tokens,
#    1295             "metadata": metadata,
#    1296             "modalities": modalities,
#    1297             "moderation": moderation,
#    1298             "n": n,
#    1299             "parallel_tool_calls": parallel_tool_calls,
#    1300             "prediction": prediction,
#    1301             "presence_penalty": presence_penalty,
#    1302             "prompt_cache_key": prompt_cache_key,
#    1303             "prompt_cache_options": prompt_cache_options,
#    1304             "prompt_cache_retention": prompt_cache_retention,
#    1305             "reasoning_effort": reasoning_effort,
#    1306             "response_format": response_format,
#    1307             "safety_identifier": safety_identifier,
#    1308             "seed": seed,
#    1309             "service_tier": service_tier,
#    1310             "stop": stop,
#    1311             "store": store,
#    1312             "stream": stream,
#    1313             "stream_options": stream_options,
#    1314             "temperature": temperature,
#    1315             "tool_choice": tool_choice,
#    1316             "tools": tools,
#    1317             "top_logprobs": top_logprobs,
#    1318             "top_p": top_p,
#    1319             "user": user,
#    1320             "verbosity": verbosity,
#    1321             "web_search_options": web_search_options,
#    1322         },
#    1323         completion_create_params.CompletionCreateParamsStreaming
#    1324         if stream
#    1325         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1326     ),
#    1327     options=make_request_options(
#    1328         extra_headers=extra_headers,
#    1329         extra_query=extra_query,
#    1330         extra_body=extra_body,
#    1331         timeout=timeout,
#    1332         security={"bearer_auth": True},
#    1333     ),
#    1334     cast_to=ChatCompletion,
#    1335     stream=stream or False,
#    1336     stream_cls=Stream[ChatCompletionChunk],
#    1337 )
#
# File /workspaces/LLM-zoomcamp/.venv/lib/python3.12/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /workspaces/LLM-zoomcamp/.venv/lib/python3.12/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1104     log.debug("Re-raising status error")
# -> 1105     raise self._make_status_error_from_response(err.response) from None
#    1107 break
#
# BadRequestError: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}}
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 eval_result, usage = evaluate_aqa(
#       2     question=rec["question"],
#       3     answer_orig=rec["answer_orig"],
#       4     answer_llm=rec["answer_llm"]
#
# Cell In[16], line 8, in evaluate_aqa(question, answer_orig, answer_llm, model)
#       4         answer_orig=answer_orig,
#       5         answer_llm=answer_llm
#       6     )
#       7
# ----> 8     result, usage = llm_structured_retry(
#       9         openai_client,
#      10         aqa_judge_instructions,
#      11         prompt,
#
# File /workspaces/LLM-zoomcamp/evaluation_utils.py:81, in llm_structured_retry(client, instructions, user_prompt, output_type, model, max_retries)
#      79     sleep_time = (attempt + 1) * 15  # Waits 15s on 1st fail, 30s on 2nd
#      80     print(f"Rate limit or API error encountered. Retrying in {sleep_time} seconds... (Error: {e})")
# ---> 81     time.sleep(sleep_time)
#      82 else:
#      83     # If we've run out of retries, raise the exception
#      84     raise e
#
# KeyboardInterrupt:

# %%
def judge_record(rec):
    eval_result, usage = evaluate_aqa(
        question=rec["question"],
        answer_orig=rec["answer_orig"],
        answer_llm=rec["answer_llm"]
    )

    result = {
        "question": rec["question"],
        "document": rec["document"],
        "score": eval_result.score,
        "reasoning": eval_result.reasoning,
    }

    return result, usage

# %%
from concurrent.futures import ThreadPoolExecutor

with ThreadPoolExecutor(max_workers=6) as pool:
    results = map_progress(pool, answers, judge_record)
# Out:
#   0%|          | 0/395 [00:00<?, ?it/s]
# Rate limit or API error encountered. Retrying in 15 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})
# Rate limit or API error encountered. Retrying in 15 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})
# Rate limit or API error encountered. Retrying in 15 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})
# Rate limit or API error encountered. Retrying in 15 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})
# Rate limit or API error encountered. Retrying in 15 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})
# Rate limit or API error encountered. Retrying in 15 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})
# Rate limit or API error encountered. Retrying in 30 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})
# Rate limit or API error encountered. Retrying in 30 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})
# Rate limit or API error encountered. Retrying in 30 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})
# Rate limit or API error encountered. Retrying in 30 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})
# Rate limit or API error encountered. Retrying in 30 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})
# Rate limit or API error encountered. Retrying in 30 seconds... (Error: Error code: 400 - {'error': {'message': '`reasoning_effort` is not supported with this model', 'type': 'invalid_request_error'}})

# %%
evaluations = []
usages = []

for evaluation, usage in results:
    evaluations.append(evaluation)
    usages.append(usage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 evaluations = []
#       2 usages = []
#       3
# ----> 4 for evaluation, usage in results:
#       5     evaluations.append(evaluation)
#       6     usages.append(usage)
#
# NameError: name 'results' is not defined

# %%
df_eval = pd.DataFrame(evaluations)

# %%
calc_total_price(usages)

# %%
good_count = (df_eval["score"] == "good").sum()
total_count = len(df_eval)
print(f"Good: {good_count}/{total_count} = {good_count/total_count:.2%}")

# %%
df_eval[df_eval["score"] == "bad"].head()

# %%
df_eval.to_csv("data/rag-evaluations-new.csv", index=False)
